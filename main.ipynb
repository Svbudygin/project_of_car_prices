# %% [markdown]
# # Car prices in Russia: DataSet analysis
# ## Introduction:
# Lots of people have their own cars, and some of them are know a lot about the pricing of different types of cars. But the fact is that no one knows exactly what prices depend on. So, someppeople suppose that sports cars from very expensive brands such as Ferrari or Lamborghini cost the most, but alas we have models of not so luxurious cars such as Mercedes that cost more. BMW  fans may argue that prices depends only on horsepower and engine type. However, this logic falters when we take into account ancient cars, with only 20 hp, costing millions of dollars. Finally, prices are not hang on a singular factor. To move deeply into this complexity of connections between horsepower, mileage, and year, I intend to show correlations, graphs, and other patterns using tools like Pandas, Matplotlib, and Seaborn.
#
# Before we get started, take a quick look at a transcript of each of the items of my dataset, which I have collected especially for you.
# * 	Brand:
#     * The brand refers to the mark of a car, such as Mercedes, BMW, Toyota, etc. It represents the manufacturer or company that produces the vehicle.
# * 	Name:
#     * The name corresponds to the specific model of car brand, such as RX 300, ML, etc.
# * 	Body Type:
#     * Provides information about the general shape and style of the vehicle, such as sedan, coupe, SUV, truck, etc.
# * 	Color:
#     * Indicates the visual appearance of the color of vehicle.
# * 	Fuel Type:
#     * Specifies the type of fuel the vehicle uses for its movement, such as gasoline, diesel, electric, hybrid, etc.
# * 	Year:
#     * Represents the manufacturing year of the vehicle.
# * 	Mileage:
#     * Refers to the total distance the vehicle has traveled, measured in kilometers.
# * 	Transmission:
#     * Describes the type of transmission system in the vehicle, such as automatic or manual.
# * 	Power:
#     * Indicates the amount of horse power the vehicle's engine produces.
# * 	Price:
#     * Shows the cost of the vehicle.
# * 	Vehicle Configuration:
#     * Describes the specific features of a particular vehicle.
# * 	Engine Name:
#     * It identifies the engine model.
# * 	Engine Displacement:
#     * Indicates the total volume of all the cylinders in the engine. It is usually measured in liters or cubic centimeters and provides information about the engine's size.
# * 	Date:
#     * Represents a specific point in time, often used in this context to indicate a relevant date related to the vehicle, such as the manufacturing date or an important event.
# * 	Location:
#     * In this context, location signifies the website where the car information is located.
# * 	Link:
#     * The link directs to the specific website or page containing information about the car.
# *   Parse date
#    * Parse Date is the time when the information about the car was entered into the dataset.
# ### For my project, I'll be use a range of libraries to analyse data and generate visualizations. Here are they:

# %%
# %matplotlib inline
# link to the dataset https://www.kaggle.com/datasets/ekibee/car-sales-information/data

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install plotly
# !pip install numpy
# !pip install seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# At first, let me demonstrate the structure of my dataset:

# %%
data = pd.read_csv('all_regions.csv')
data
# Out:
#               brand           name       bodyType        color fuelType  \
# 0        Volkswagen           Golf  Хэтчбек 5 дв.  Серебристый   Бензин
# 1              Лада       1111 Ока  Хэтчбек 3 дв.   Фиолетовый   Бензин
# 2            Toyota       Funcargo  Хэтчбек 5 дв.  Серебристый   Бензин
# 3              Лада         Гранта        Лифтбек        Серый   Бензин
# 4              Лада    Нива Легенд     Джип 3 дв.      Зеленый   Бензин
# ...             ...            ...            ...          ...      ...
# 1294752         BMW             X1     Джип 5 дв.        Серый   Дизель
# 1294753        Лада           2105          Седан        Белый   Бензин
# 1294754      Toyota          Camry          Седан        Серый   Бензин
# 1294755        Лада  4x4 2121 Нива     Джип 3 дв.        Белый   Бензин
# 1294756        Лада  4x4 2121 Нива     Джип 3 дв.        Белый   Бензин
#
#            year   mileage transmission  power    price vehicleConfiguration  \
# 0           NaN  240000.0     Механика  101.0   280000                  NaN
# 1        1996.0   37000.0     Механика   33.0    95000         0.6 MT 11113
# 2        2002.0  295000.0         АКПП   87.0   380000                1.3 J
# 3        2018.0   16000.0     Механика  106.0   795000       1.6 MT Comfort
# 4           NaN       NaN     Механика   83.0  1022900                  NaN
# ...         ...       ...          ...    ...      ...                  ...
# 1294752     NaN  275000.0         АКПП  177.0  1000000                  NaN
# 1294753  1985.0  300000.0     Механика   64.0   165000        1.3 MT5 21050
# 1294754  2020.0   32000.0         АКПП  202.0  3100000            2.5 AT SE
# 1294755  1995.0  354000.0     Механика   79.0   298000               1.7 MT
# 1294756  1995.0  354000.0     Механика   79.0   320000               1.7 MT
#
#         engineName engineDisplacement                 date      location  \
# 0              NaN                NaN  2023-04-02 00:00:00        Майкоп
# 1        ВАЗ-11113            0.7 LTR  2023-04-02 00:00:00        Майкоп
# 2           2NZ-FE            1.3 LTR  2023-04-02 00:00:00        Майкоп
# 3        ВАЗ-21127            1.6 LTR  2023-04-02 00:00:00        Майкоп
# 4              NaN                NaN  2023-04-02 00:00:00   Яблоновский
# ...            ...                ...                  ...           ...
# 1294752        NaN                NaN  2023-06-01 00:00:00      Черкесск
# 1294753   ВАЗ-2105            1.3 LTR  2023-06-01 00:00:00  Усть-Джегута
# 1294754   A25A-FKS            2.5 LTR  2023-06-01 00:00:00      Черкесск
# 1294755  ВАЗ-21213            1.7 LTR  2023-06-01 00:00:00      Черкесск
# 1294756  ВАЗ-21213            1.7 LTR  2023-06-01 00:00:00      Черкесск
#
#                                                       link  \
# 0        https://maykop.drom.ru/volkswagen/golf/5001300...
# 1            https://maykop.drom.ru/lada/oka/50378140.html
# 2        https://maykop.drom.ru/toyota/funcargo/5037751...
# 3         https://maykop.drom.ru/lada/granta/50382492.html
# 4        https://yablonovskiy.drom.ru/lada/niva_legend/...
# ...                                                    ...
# 1294752     https://cherkessk.drom.ru/bmw/x1/51154874.html
# 1294753  https://ust-dzheguta.drom.ru/lada/2105/5114990...
# 1294754  https://cherkessk.drom.ru/toyota/camry/5115596...
# 1294755  https://cherkessk.drom.ru/lada/2121_4x4_niva/5...
# 1294756  https://cherkessk.drom.ru/lada/2121_4x4_niva/5...
#
#                                                description  \
# 0        101 л.с. люк не течёт. Документы в порядке. Со...
# 1        Ваз Ока Год: 2003 Цвет: Баклажан, в ПТС так и ...
# 2        ХОРОШЕЕ СОСТОЯНИЕ. замена комплекта грм и помп...
# 3        Автомобиль в отличном техническом состоянии, н...
# 4        Модель: Нива Легенд Комплектация: LADA (ВАЗ) N...
# ...                                                    ...
# 1294752  Продам автомобиль BMW X1 2d в идеальном состоя...
# 1294753  продаю автомобиль изо не надобности автомобиль...
# 1294754  Америнка,в отличном состоянии,любые проверки. ...
# 1294755  Нива в хорошем состоянии, без гнили, лонжероны...
# 1294756  Нива в хорошем состоянии, без гнили, лонжероны...
#
#                   parse_date
# 0        2023-05-02 01:00:00
# 1        2023-05-02 20:00:00
# 2        2023-05-02 20:00:00
# 3        2023-05-02 23:00:00
# 4        2023-05-02 20:00:00
# ...                      ...
# 1294752  2023-06-01 21:00:00
# 1294753  2023-06-01 13:00:00
# 1294754  2023-06-01 20:00:00
# 1294755  2023-06-01 23:00:00
# 1294756  2023-06-01 21:00:00
#
# [1294757 rows x 18 columns]

# %% [markdown]
# # Data cleanup and Transformation
# ## In this table, there are numerous missing values. Let me work with them
# 1) Initially, if the year information is absent, it would be great to compute the mean year for cars with the same name (model). However, if a vehicle's name uniquely identified, then finding its year becomes impossible, so I decided to drop this rows from my dataset.
# 2) Similarly, I will apply the same strategy to the power column. To execute this, I will construct a pivot table and introduce two new columns, that will display the average horsepower and year for each car name (model).
# 3) As for mileage, a NaN value implies a new vehicle with the mileage value of 0.
# 4) Non-numeric columns will have NaN entries replaced with 'information not given,' as these columns serve just additional details.
# 5) In the interest of making analysis more simple, I have dropped columns such as 'description,' 'link,' 'location,' and 'parse_date'.
# 6) Furthermore, I have standardized the column names to lowercase.
# 7) For "fuel type", "transmission", "name", "brand" and "price", I removed rows containing deleted NaN entries. This step is very important because attempting to replace NaN values in these columns is not possible due to lack of information.
# 8) I have also change NaN values in the 'color' column by "Белый," following the common practice on Auto.ru, where an absence of color denotes as a white vehicle.
# 9) Additionally, I have reset the indices and reform certain columns, including 'power,' 'year,' and 'mileage,' to integer format.

# %%
def int_mean(arg):
    try:
        return int(arg.mean())
    except ValueError:
        return np.nan


pivot_data = data.pivot_table(index='name', values=['year', 'power', 'price'], aggfunc=int_mean)
print(pivot_data)
# Out:
#              power     price    year
# name
# 001            NaN   7431448  2021.0
# 009            NaN  11800000     NaN
# 05           254.0   4899000     NaN
# 09           385.0   7729482     NaN
# 1-Series     136.0   1119534  2009.0
# ...            ...       ...     ...
# Х-рей        111.0    880878  2017.0
# Х-рей Кросс  117.0   1248434  2019.0
# Хантер       123.0    700439  2009.0
# Чайка        172.0   6750000     NaN
# Шанс          78.0    186460  2008.0
#
# [2223 rows x 3 columns]

# %%
data = data.merge(pivot_data, on='name', how='left', suffixes=('', '_average'))

data.loc[data['year'].isna(), 'year'] = data.year_average
data.loc[data['power'].isna(), 'power'] = data.power_average
data.head()
# Out:
#         brand         name       bodyType        color fuelType    year  \
# 0  Volkswagen         Golf  Хэтчбек 5 дв.  Серебристый   Бензин  2005.0
# 1        Лада     1111 Ока  Хэтчбек 3 дв.   Фиолетовый   Бензин  1996.0
# 2      Toyota     Funcargo  Хэтчбек 5 дв.  Серебристый   Бензин  2002.0
# 3        Лада       Гранта        Лифтбек        Серый   Бензин  2018.0
# 4        Лада  Нива Легенд     Джип 3 дв.      Зеленый   Бензин  2022.0
#
#     mileage transmission  power    price  ... engineName engineDisplacement  \
# 0  240000.0     Механика  101.0   280000  ...        NaN                NaN
# 1   37000.0     Механика   33.0    95000  ...  ВАЗ-11113            0.7 LTR
# 2  295000.0         АКПП   87.0   380000  ...     2NZ-FE            1.3 LTR
# 3   16000.0     Механика  106.0   795000  ...  ВАЗ-21127            1.6 LTR
# 4       NaN     Механика   83.0  1022900  ...        NaN                NaN
#
#                   date     location  \
# 0  2023-04-02 00:00:00       Майкоп
# 1  2023-04-02 00:00:00       Майкоп
# 2  2023-04-02 00:00:00       Майкоп
# 3  2023-04-02 00:00:00       Майкоп
# 4  2023-04-02 00:00:00  Яблоновский
#
#                                                 link  \
# 0  https://maykop.drom.ru/volkswagen/golf/5001300...
# 1      https://maykop.drom.ru/lada/oka/50378140.html
# 2  https://maykop.drom.ru/toyota/funcargo/5037751...
# 3   https://maykop.drom.ru/lada/granta/50382492.html
# 4  https://yablonovskiy.drom.ru/lada/niva_legend/...
#
#                                          description           parse_date  \
# 0  101 л.с. люк не течёт. Документы в порядке. Со...  2023-05-02 01:00:00
# 1  Ваз Ока Год: 2003 Цвет: Баклажан, в ПТС так и ...  2023-05-02 20:00:00
# 2  ХОРОШЕЕ СОСТОЯНИЕ. замена комплекта грм и помп...  2023-05-02 20:00:00
# 3  Автомобиль в отличном техническом состоянии, н...  2023-05-02 23:00:00
# 4  Модель: Нива Легенд Комплектация: LADA (ВАЗ) N...  2023-05-02 20:00:00
#
#   power_average  price_average  year_average
# 0         112.0         784790        2005.0
# 1          33.0          86463        1995.0
# 2          92.0         341564        2000.0
# 3          90.0         687676        2018.0
# 4          82.0         874968        2022.0
#
# [5 rows x 21 columns]

# %%
print(data.shape)
data.dropna(axis=0, inplace=True, how='any', subset=['year', 'power'])
print(data.shape)
# Out:
# (1294757, 21)
# (1282314, 21)

# %%
NG = 'information not given'
data = data.fillna(
    {'mileage': 0, 'bodyType': NG, 'vehicleConfiguration': NG, 'engineName': NG, 'engineDisplacement': NG,
     'color': 'Белый'})
data.head()
# Out:
#         brand         name       bodyType        color fuelType    year  \
# 0  Volkswagen         Golf  Хэтчбек 5 дв.  Серебристый   Бензин  2005.0
# 1        Лада     1111 Ока  Хэтчбек 3 дв.   Фиолетовый   Бензин  1996.0
# 2      Toyota     Funcargo  Хэтчбек 5 дв.  Серебристый   Бензин  2002.0
# 3        Лада       Гранта        Лифтбек        Серый   Бензин  2018.0
# 4        Лада  Нива Легенд     Джип 3 дв.      Зеленый   Бензин  2022.0
#
#     mileage transmission  power    price  ...             engineName  \
# 0  240000.0     Механика  101.0   280000  ...  information not given
# 1   37000.0     Механика   33.0    95000  ...              ВАЗ-11113
# 2  295000.0         АКПП   87.0   380000  ...                 2NZ-FE
# 3   16000.0     Механика  106.0   795000  ...              ВАЗ-21127
# 4       0.0     Механика   83.0  1022900  ...  information not given
#
#       engineDisplacement                 date     location  \
# 0  information not given  2023-04-02 00:00:00       Майкоп
# 1                0.7 LTR  2023-04-02 00:00:00       Майкоп
# 2                1.3 LTR  2023-04-02 00:00:00       Майкоп
# 3                1.6 LTR  2023-04-02 00:00:00       Майкоп
# 4  information not given  2023-04-02 00:00:00  Яблоновский
#
#                                                 link  \
# 0  https://maykop.drom.ru/volkswagen/golf/5001300...
# 1      https://maykop.drom.ru/lada/oka/50378140.html
# 2  https://maykop.drom.ru/toyota/funcargo/5037751...
# 3   https://maykop.drom.ru/lada/granta/50382492.html
# 4  https://yablonovskiy.drom.ru/lada/niva_legend/...
#
#                                          description           parse_date  \
# 0  101 л.с. люк не течёт. Документы в порядке. Со...  2023-05-02 01:00:00
# 1  Ваз Ока Год: 2003 Цвет: Баклажан, в ПТС так и ...  2023-05-02 20:00:00
# 2  ХОРОШЕЕ СОСТОЯНИЕ. замена комплекта грм и помп...  2023-05-02 20:00:00
# 3  Автомобиль в отличном техническом состоянии, н...  2023-05-02 23:00:00
# 4  Модель: Нива Легенд Комплектация: LADA (ВАЗ) N...  2023-05-02 20:00:00
#
#   power_average  price_average  year_average
# 0         112.0         784790        2005.0
# 1          33.0          86463        1995.0
# 2          92.0         341564        2000.0
# 3          90.0         687676        2018.0
# 4          82.0         874968        2022.0
#
# [5 rows x 21 columns]

# %%
data = data.drop(['description', 'link', 'location', 'parse_date'], axis=1)
data.head()
# Out:
#         brand         name       bodyType        color fuelType    year  \
# 0  Volkswagen         Golf  Хэтчбек 5 дв.  Серебристый   Бензин  2005.0
# 1        Лада     1111 Ока  Хэтчбек 3 дв.   Фиолетовый   Бензин  1996.0
# 2      Toyota     Funcargo  Хэтчбек 5 дв.  Серебристый   Бензин  2002.0
# 3        Лада       Гранта        Лифтбек        Серый   Бензин  2018.0
# 4        Лада  Нива Легенд     Джип 3 дв.      Зеленый   Бензин  2022.0
#
#     mileage transmission  power    price   vehicleConfiguration  \
# 0  240000.0     Механика  101.0   280000  information not given
# 1   37000.0     Механика   33.0    95000           0.6 MT 11113
# 2  295000.0         АКПП   87.0   380000                  1.3 J
# 3   16000.0     Механика  106.0   795000         1.6 MT Comfort
# 4       0.0     Механика   83.0  1022900  information not given
#
#               engineName     engineDisplacement                 date  \
# 0  information not given  information not given  2023-04-02 00:00:00
# 1              ВАЗ-11113                0.7 LTR  2023-04-02 00:00:00
# 2                 2NZ-FE                1.3 LTR  2023-04-02 00:00:00
# 3              ВАЗ-21127                1.6 LTR  2023-04-02 00:00:00
# 4  information not given  information not given  2023-04-02 00:00:00
#
#    power_average  price_average  year_average
# 0          112.0         784790        2005.0
# 1           33.0          86463        1995.0
# 2           92.0         341564        2000.0
# 3           90.0         687676        2018.0
# 4           82.0         874968        2022.0

# %%
data.columns = data.columns.str.lower()
data.tail()
# Out:
#           brand           name    bodytype  color fueltype    year   mileage  \
# 1294752     BMW             X1  Джип 5 дв.  Серый   Дизель  2013.0  275000.0
# 1294753    Лада           2105       Седан  Белый   Бензин  1985.0  300000.0
# 1294754  Toyota          Camry       Седан  Серый   Бензин  2020.0   32000.0
# 1294755    Лада  4x4 2121 Нива  Джип 3 дв.  Белый   Бензин  1995.0  354000.0
# 1294756    Лада  4x4 2121 Нива  Джип 3 дв.  Белый   Бензин  1995.0  354000.0
#
#         transmission  power    price   vehicleconfiguration  \
# 1294752         АКПП  177.0  1000000  information not given
# 1294753     Механика   64.0   165000          1.3 MT5 21050
# 1294754         АКПП  202.0  3100000              2.5 AT SE
# 1294755     Механика   79.0   298000                 1.7 MT
# 1294756     Механика   79.0   320000                 1.7 MT
#
#                     enginename     enginedisplacement                 date  \
# 1294752  information not given  information not given  2023-06-01 00:00:00
# 1294753               ВАЗ-2105                1.3 LTR  2023-06-01 00:00:00
# 1294754               A25A-FKS                2.5 LTR  2023-06-01 00:00:00
# 1294755              ВАЗ-21213                1.7 LTR  2023-06-01 00:00:00
# 1294756              ВАЗ-21213                1.7 LTR  2023-06-01 00:00:00
#
#          power_average  price_average  year_average
# 1294752          169.0        1880223        2013.0
# 1294753           71.0          93859        1991.0
# 1294754          179.0        1834807        2009.0
# 1294755           80.0         404464        1998.0
# 1294756           80.0         404464        1998.0

# %%
data.dropna(axis=0, inplace=True, how='any', subset=['fueltype', 'transmission', 'name', 'brand', 'price'])
print(data.shape)
# Out:
# (1275110, 17)

# %%
data = data.reset_index(drop=True)
data.year = data.year.apply(int)
data.power = data.power.apply(int)
data.mileage = data.mileage.apply(int)
data.head()
# Out:
#         brand         name       bodytype        color fueltype  year  \
# 0  Volkswagen         Golf  Хэтчбек 5 дв.  Серебристый   Бензин  2005
# 1        Лада     1111 Ока  Хэтчбек 3 дв.   Фиолетовый   Бензин  1996
# 2      Toyota     Funcargo  Хэтчбек 5 дв.  Серебристый   Бензин  2002
# 3        Лада       Гранта        Лифтбек        Серый   Бензин  2018
# 4        Лада  Нива Легенд     Джип 3 дв.      Зеленый   Бензин  2022
#
#    mileage transmission  power    price   vehicleconfiguration  \
# 0   240000     Механика    101   280000  information not given
# 1    37000     Механика     33    95000           0.6 MT 11113
# 2   295000         АКПП     87   380000                  1.3 J
# 3    16000     Механика    106   795000         1.6 MT Comfort
# 4        0     Механика     83  1022900  information not given
#
#               enginename     enginedisplacement                 date  \
# 0  information not given  information not given  2023-04-02 00:00:00
# 1              ВАЗ-11113                0.7 LTR  2023-04-02 00:00:00
# 2                 2NZ-FE                1.3 LTR  2023-04-02 00:00:00
# 3              ВАЗ-21127                1.6 LTR  2023-04-02 00:00:00
# 4  information not given  information not given  2023-04-02 00:00:00
#
#    power_average  price_average  year_average
# 0          112.0         784790        2005.0
# 1           33.0          86463        1995.0
# 2           92.0         341564        2000.0
# 3           90.0         687676        2018.0
# 4           82.0         874968        2022.0

# %% [markdown]
# # Descriptive statistics
# <b>I have opted to provide a description of 'year,' 'mileage,' 'power,' and 'price,' by showing their mean, minimum, maximum, median, and standard deviation values</b> because understanding these statistical measures is crucial for understanding the hole picture of my dataset. By analyzing the mean, I can identify the average values, while the minimum and maximum values presents the range and extremities of the data. The median helps to find the central tendency, and the standard deviation quantifies the dispersion of values around the mean. This  statistical overview is essential for identifying trends and denoting the usability of the dataset.

# %%
print(data.info())
print(f'Shape of the dataset: {data.shape[0]} rows by {data.shape[1]} columns')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275110 entries, 0 to 1275109
# Data columns (total 17 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   brand                 1275110 non-null  object
#  1   name                  1275110 non-null  object
#  2   bodytype              1275110 non-null  object
#  3   color                 1275110 non-null  object
#  4   fueltype              1275110 non-null  object
#  5   year                  1275110 non-null  int64
#  6   mileage               1275110 non-null  int64
#  7   transmission          1275110 non-null  object
#  8   power                 1275110 non-null  int64
#  9   price                 1275110 non-null  int64
#  10  vehicleconfiguration  1275110 non-null  object
#  11  enginename            1275110 non-null  object
#  12  enginedisplacement    1275110 non-null  object
#  13  date                  1275110 non-null  object
#  14  power_average         1275110 non-null  float64
#  15  price_average         1275110 non-null  int64
#  16  year_average          1275110 non-null  float64
# dtypes: float64(2), int64(5), object(10)
# memory usage: 165.4+ MB
# None
# Shape of the dataset: 1275110 rows by 17 columns

# %%
data[['year', 'mileage', 'power', 'price']].std()
# Out:
# year       8.630094e+00
# mileage    1.087760e+05
# power      6.546960e+01
# price      1.955797e+06
# dtype: float64

# %%
x = [['median', data['year'].median(), data['mileage'].median(), data['power'].median(), data['price'].median()],
     ['mean', data['year'].mean(), data['mileage'].mean(), data['power'].mean(), data['price'].mean()],
     ['max', data['year'].max(), data['mileage'].max(), data['power'].max(), data['price'].max()],
     ['min', data['year'].min(), data['mileage'].min(), data['power'].min(), data['price'].min()]]
pd.DataFrame(x, columns=['name', 'year', 'mileage', 'power', 'price'])
# Out:
#      name         year         mileage        power         price
# 0  median  2010.000000    57000.000000   128.000000  8.700000e+05
# 1    mean  2009.584212    92639.992628   141.604902  1.437479e+06
# 2     max  2023.000000  1000000.000000  1000.000000  1.500000e+08
# 3     min  1936.000000        0.000000     1.000000  2.700000e+02

# %%
lst = ['brand', 'power', 'price']
new = data[lst].groupby(by='brand').mean()
new.head()
# Out:
#                    power         price
# brand
# AITO          559.000000  5.900000e+06
# Acura         260.548052  1.390738e+06
# Alfa Romeo    181.469136  9.565954e+05
# Aston Martin  492.714286  1.084350e+07
# Audi          212.728119  2.399239e+06

# %% [markdown]
# # Overview
# ## After cleaning up our file, adding a few columns, and rearranging the rows, we have observed the key statistics of our dataset. We now a lot about the values and items we will be working with. It's time to visualize straightforward aspects.
#
# I have chosen to create several line graphs that compare price and year, mileage and price, and mileage and power. As for the last comparison, it may initially seem unreasonable, but, as depicted below, there are some consistencies. Additionally, I have opted to generate statistics specifically for Mercedes-Benz, rather than for every car, to make my comparisons are more beautiful and to avoid cluttering the statistics.

# %%
merc1 = data.loc[data['brand'] == 'Mercedes-Benz']
merc = merc1.sort_values(by=['price', 'year', 'mileage', 'power'], ascending=True)
plt.subplot(2, 2, 1)
plt.plot(merc['price'], merc['year'])
plt.xlabel('price')
plt.ylabel('year')
# plt.legend()
plt.subplot(2, 2, 2)
plt.xlabel('price')
plt.ylabel('mileage')
plt.plot(merc['price'], merc['mileage'])
# plt.legend()
plt.subplot(2, 1, 2)
plt.ylabel('mileage')
plt.xlabel('power')
plt.scatter(merc['power'], merc['mileage'], s=0.6, alpha=0.3)
# plt.legend()

plt.show()

# %%
px.histogram(data.year,
             marginal="box",
             nbins=50,
             barmode="overlay",
             title="The number of cars on the market by year of production")

# %%
vc = data['brand'].value_counts()
piedf = pd.DataFrame(data=zip(vc.index, vc.values))

px.pie(piedf, values=1,
       names=0,
       title="The number of cars on the market by brands",
       hole=0.3).update_traces(textposition="inside", textinfo="percent+label")

# %% [markdown]
# My another plot, presented in the form of a histogram, was made to quickly understand the number of cars of specific brands by their number on the market.

# %%
ax = data.loc[data.brand == 'Toyota', 'year'].plot(kind='hist', alpha=0.3, label='Toyota')
data.loc[data.brand == 'Volkswagen', 'year'].plot(kind='hist', alpha=0.3, ax=ax, label='Volkswagen')
data.loc[data.brand == 'Chevrolet', 'year'].plot(kind='hist', alpha=0.3, ax=ax, label='Chevrolet')
ax.yaxis.set_label_text('Quantity')
ax.set_title('The quantity of Toyota, Volkswagen, and Chevrolet on the market.')
plt.legend()
plt.show()

# %% [markdown]
# The next two graphs take the form of scatter plots, show the correlation between price and year for all cars and Mercedes-Benz specifically in the dataset. These visualizations aim to provide a understanding of how the pricing figure changes the years for all cars and the specific brand.

# %%
px.scatter(data, x='year', y='price', log_y=[0.01, 3000_000_000], log_x=[0.01, 1000000])
# средние по году общий тренд

# %%
px.scatter(merc1, x='year', y='price', log_y=[0, 10_000_000])
# titles записать везде

# %% [markdown]
# As for last plot but not least, I've presented two graphs depicting the count of Mercedes-Benz vehicles on the market through the years and horsepower. These visualizations give us information of the availability of Mercedes-Benz cars over different years and their horsepower.

# %%
plt.subplot(1, 2, 1)
plt.hist(merc1['power'], color='Orange')
plt.xlabel('power')
plt.ylabel('amount')
plt.subplot(1, 2, 2)
plt.hist(merc1['year'])
plt.xlabel('year')
plt.ylabel('amount')
plt.title('Amount of Mercedes-Benz on the market through the years and horsepower')
plt.show()

# %% [markdown]
# # More Detailed overview
# As we explore our data set further, it becomes necessary to print out a correlation analysis that shows linear relationships between two variables. By focusing on our number columns (price, year, horsepower, mileage), I intend to find out the relationships between these values and identify hidden trends, indirect associations and dependencies.

# %%
y = data[['price', 'year', 'mileage', 'power']]
corr = y.corr().style.background_gradient(cmap='coolwarm')
print(corr.data)
px.imshow(data[['price', 'year', 'mileage', 'power']].corr())
# Out:
#             price      year   mileage     power
# price    1.000000  0.400534 -0.267206  0.608761
# year     0.400534  1.000000 -0.363736  0.185184
# mileage -0.267206 -0.363736  1.000000 -0.045202
# power    0.608761  0.185184 -0.045202  1.000000

# %%
pd.plotting.scatter_matrix(pd.DataFrame(data=data, columns=['price', 'year', 'mileage', 'power']), figsize=(20, 10))
plt.show()

# %% [markdown]
# 1. <u><b>Price vs. Year (0.400534):</u></b>
#
#    The positive correlation between car price and the year of manufacture (0.40) indicates that, on average, newer cars tend to have higher prices, all this could be because of innovative technology, safety features, and overall improvements in newer models.
#
# 2. <u><b>Price vs. Mileage (-0.267206):</u></b>
#
#    The negative correlation between car price and mileage (-0.27) suggests that, in general, lower mileage is associated with higher prices.
#
# 3.  <u><b>Price vs. Power (0.608761):</u></b>
#
#     The strong positive correlation (0.61) between car price and horsepower implies that there is a substantial influence of engine power on pricing, so it really true, because buyers seem willing to pay more for cars with more horsepower.
#
# 4. <u><b>Year vs. Mileage (-0.363736):</u></b>
#
#    The negative correlation (-0.36) between the year of manufacture and mileage indicates that newer cars tend to have lower mileage. This obvious fact could be attributed to the fact that older cars are have accumulated more kilometers over time.
#
# 5. <u><b>Year vs. Power (0.185184):</u></b>
#
#   The weak positive correlation (0.19) between year of manufacture and power indicates a subtle relationship.
#
# 6. <u><b>Mileage vs. Power (-0.045202):</u></b>
#
#    The very weak negative correlation (-0.05) between mileage and horsepower implies that there is no clear relationship between a car's mileage and its horsepower.
#
# 7. <u><b>Causation Note:</u></b>
#
#    Correlations show connections, but more evidence is needed to prove causation.
#
# 8. <u><b>Visualizing Data:</u></b>
#
#    Using graphs such as scatter plots or regression plots can help you better understand relationships. Visual examination may reveal nonlinear trends that are not fully captured by correlation coefficients, which is why I included the graphs.

# %%
df = data
df['branding'] = 'Other'
df.loc[df['brand'].str.contains('Mercedes-Benz', case=False), 'branding'] = 'Mercedes'
df.loc[df['brand'].str.contains('BMW', case=False), 'branding'] = 'BMW'
df.loc[df['brand'].str.contains('Audi', case=False), 'branding'] = 'Audi'
df.loc[df['brand'].str.contains('Toyota', case=False), 'branding'] = 'Toyota'
fig = plt.figure(figsize=(100, 7))
ax = fig.add_subplot(111, projection='3d')

x = df['year']
y = df['mileage']
z = df['price']

colors = {'Mercedes': 'red', 'BMW': 'blue', 'Audi': 'green', 'Toyota': 'orange', 'Other': 'gray'}
df['Color'] = df['branding'].map(colors)

ax.scatter(x, y, z, c=df['Color'], marker='o')

ax.set_xlabel('Year')
ax.set_ylabel('Mileage')
ax.set_zlabel('Price')
ax.set_title('3D Plot of Price, Year, and Mileage by Brand')

for brand, color in colors.items():
    ax.scatter([], [], [], c=color, label=brand)

ax.legend()

plt.show()

# %% [markdown]
# A 3D graph illustrates the relationship between the year of manufacture, mileage and price of Mercedes, Toyota, BMW, Audi and others. Key observations include:
#
# - Year compared to price:
# New cars tend to have higher prices, with different trends for each brand. Looking at our data, we can notice some interesting things: Mercedes-Benz has a lot of new cars, and they should be more expensive than Toyota. There are also quite a few Toyotas with high mileage. In the BMW category, most cars are priced lower than Mercedes, with the exception of those that are more expensive than most Audi cars.
# - Mileage vs price:
# There are significant differences in mileage for each brand.
# - Brand differentiation:
# Colored dots differentiate brands by highlighting unique pricing and mileage trends.
# - Information for further analysis:
# Questions arise about factors influencing pricing, but to understand this we need more in-depth research.

# %% [markdown]
# # My Hypothesis
# Regarding this hypothesis, I believe that the price of a car depends on several factors:
#
# When it comes to vehicle pricing, brand luxury stands for 10%, with fuel type and transmission sharing a similar percentage, taking another 10%. Power plays a great role, accounting for 20%, and more significantly 30% is related to mileage. The remaining 30% is distributed among various other parameters.
#
# My idea involves restructuring our data set. I plan to introduce a new columns that contains types of fuel, represented digitally. Additionally, I aim to rearrange car brands into three types based on their luxury status, taking into account car prices and horsepower. To uncover the truth I intend to  explore the correlations.

# %%
def change_fuel(fuel):
    if fuel.lower() == "бензин":
        return 1
    if fuel.lower() == 'дизель':
        return 2
    return 3


def change_tr(tr):
    if tr == 'Механика':
        return 1
    return 2


data['trms'] = data.transmission.apply(change_tr)
data['fuel'] = data.fueltype.apply(change_fuel)
data.head()
# Out:
#         brand         name       bodytype        color fueltype  year  \
# 0  Volkswagen         Golf  Хэтчбек 5 дв.  Серебристый   Бензин  2005
# 1        Лада     1111 Ока  Хэтчбек 3 дв.   Фиолетовый   Бензин  1996
# 2      Toyota     Funcargo  Хэтчбек 5 дв.  Серебристый   Бензин  2002
# 3        Лада       Гранта        Лифтбек        Серый   Бензин  2018
# 4        Лада  Нива Легенд     Джип 3 дв.      Зеленый   Бензин  2022
#
#    mileage transmission  power    price  ...             enginename  \
# 0   240000     Механика    101   280000  ...  information not given
# 1    37000     Механика     33    95000  ...              ВАЗ-11113
# 2   295000         АКПП     87   380000  ...                 2NZ-FE
# 3    16000     Механика    106   795000  ...              ВАЗ-21127
# 4        0     Механика     83  1022900  ...  information not given
#
#       enginedisplacement                 date power_average  price_average  \
# 0  information not given  2023-04-02 00:00:00         112.0         784790
# 1                0.7 LTR  2023-04-02 00:00:00          33.0          86463
# 2                1.3 LTR  2023-04-02 00:00:00          92.0         341564
# 3                1.6 LTR  2023-04-02 00:00:00          90.0         687676
# 4  information not given  2023-04-02 00:00:00          82.0         874968
#
#    year_average  branding   Color trms  fuel
# 0        2005.0     Other    gray    1     1
# 1        1995.0     Other    gray    1     1
# 2        2000.0    Toyota  orange    2     1
# 3        2018.0     Other    gray    1     1
# 4        2022.0     Other    gray    1     1
#
# [5 rows x 21 columns]

# %%
data.head()


def int_mean(arg):
    try:
        return int(arg.mean())
    except ValueError:
        return np.nan


def lux(car_bruum):
    global cm, pm
    return car_bruum / cm * 2


def lux1(pow):
    global cm, pm
    return pow / pm


pivot_df = data.pivot_table(index='brand', values=['price', 'power', ], aggfunc=int_mean)
data = data.merge(pivot_df, on='brand', how='left', suffixes=('', '_avrg_brand'))
cm = data.price_avrg_brand.mean()
pm = data.power_avrg_brand.mean()

data.tail()
# Out:
#           brand           name    bodytype  color fueltype  year  mileage  \
# 1275105     BMW             X1  Джип 5 дв.  Серый   Дизель  2013   275000
# 1275106    Лада           2105       Седан  Белый   Бензин  1985   300000
# 1275107  Toyota          Camry       Седан  Серый   Бензин  2020    32000
# 1275108    Лада  4x4 2121 Нива  Джип 3 дв.  Белый   Бензин  1995   354000
# 1275109    Лада  4x4 2121 Нива  Джип 3 дв.  Белый   Бензин  1995   354000
#
#         transmission  power    price  ...                 date power_average  \
# 1275105         АКПП    177  1000000  ...  2023-06-01 00:00:00         169.0
# 1275106     Механика     64   165000  ...  2023-06-01 00:00:00          71.0
# 1275107         АКПП    202  3100000  ...  2023-06-01 00:00:00         179.0
# 1275108     Механика     79   298000  ...  2023-06-01 00:00:00          80.0
# 1275109     Механика     79   320000  ...  2023-06-01 00:00:00          80.0
#
#         price_average year_average  branding   Color  trms fuel  \
# 1275105       1880223       2013.0       BMW    blue     2    2
# 1275106         93859       1991.0     Other    gray     1    1
# 1275107       1834807       2009.0    Toyota  orange     2    1
# 1275108        404464       1998.0     Other    gray     1    1
# 1275109        404464       1998.0     Other    gray     1    1
#
#         power_avrg_brand  price_avrg_brand
# 1275105              241           3422132
# 1275106               86            461527
# 1275107              139           1303645
# 1275108               86            461527
# 1275109               86            461527
#
# [5 rows x 23 columns]

# %%
data['luxury'] = data['price_avrg_brand'].apply(lux) + data['power_avrg_brand'].apply(lux1)
data.head()
# Out:
#         brand         name       bodytype        color fueltype  year  \
# 0  Volkswagen         Golf  Хэтчбек 5 дв.  Серебристый   Бензин  2005
# 1        Лада     1111 Ока  Хэтчбек 3 дв.   Фиолетовый   Бензин  1996
# 2      Toyota     Funcargo  Хэтчбек 5 дв.  Серебристый   Бензин  2002
# 3        Лада       Гранта        Лифтбек        Серый   Бензин  2018
# 4        Лада  Нива Легенд     Джип 3 дв.      Зеленый   Бензин  2022
#
#    mileage transmission  power    price  ... power_average price_average  \
# 0   240000     Механика    101   280000  ...         112.0        784790
# 1    37000     Механика     33    95000  ...          33.0         86463
# 2   295000         АКПП     87   380000  ...          92.0        341564
# 3    16000     Механика    106   795000  ...          90.0        687676
# 4        0     Механика     83  1022900  ...          82.0        874968
#
#   year_average branding   Color  trms  fuel power_avrg_brand price_avrg_brand  \
# 0       2005.0    Other    gray     1     1              144          1516654
# 1       1995.0    Other    gray     1     1               86           461527
# 2       2000.0   Toyota  orange     2     1              139          1303645
# 3       2018.0    Other    gray     1     1               86           461527
# 4       2022.0    Other    gray     1     1               86           461527
#
#      luxury
# 0  3.130276
# 1  1.251371
# 2  2.798490
# 3  1.251371
# 4  1.251371
#
# [5 rows x 24 columns]

# %%
pd.plotting.scatter_matrix(pd.DataFrame(data=data, columns=['price', 'luxury', 'fuel', 'trms', 'power', 'mileage']), figsize=(20, 10))
plt.show()

# %% [markdown]
# Returning to my hypothesis, let's analyse its key aspects:
#
#
# 1) The dependence of price on fuel and transmission close to each other, sharing a proportional percentage.
# 2) Interestingly, this percentage weighs almost like the ratio given to the luxury factor in the pricing dependance equation.
# 3) On the other hand, the power of a given vehicle is expected to have twice the impact on its price compared to the combined effects of fuel and transmission.
# 4) Significantly, and according to my assumption, the main factor affecting price is the mileage, which waits three times more than luxury.
#
# Let's delve into correlations to find the truth.

# %%
plt.figure()
sns.heatmap(data[['price', 'luxury', 'fuel', 'trms', 'power', 'mileage']].corr(), annot=True, fmt='.4f', linewidths=.5, cmap='winter')
plt.show()

# %% [markdown]
# * 	Price vs. Luxury (0.509580):
# There is a moderate positive correlation between price and luxury. This suggests that as the price of a car increases, it is likely to be associated with higher perceived luxury.
# * 	Price vs. Fuel Efficiency (0.253799):
# There is a positive correlation between price and fuel efficiency, although it is relatively weak. This could mean that higher-priced cars tend to have slightly better fuel efficiency, but the relationship is not very strong.
# * 	Price vs. Transmission (0.289304):
# There is a positive correlation between price and transmission. This could indicate that higher-priced cars are more likely to have certain transmission features or qualities.
# * 	Price vs. Power (0.608761):
# There is a strong positive correlation between price and power. This suggests that more expensive cars are likely to have higher power or engine performance.
# * 	Price vs. Mileage (-0.267206):
# There is a negative correlation between price and mileage. This implies that as the price of a car increases, it is likely to be associated with lower mileage, which means higher-end cars may sacrifice fuel efficiency for other performance features.
#
# The most significant correlations with the price are observed with power (0.6), followed by luxury (0.5), and then transmission (0.28). Surprisingly, mileage (-0.26) and the type of fuel (0.25) exhibit comparatively weaker relationships with price...
#
# Contrary to initial expectations, the analysis reveals that power plays a more crucial role than mileage in influencing the price. Furthermore, it is interesting to note that price doesn't significantly depend on mileage. Transmission and fuel show similar correlation grades, aligning with the initial assumptions. A noteworthy finding is the substantial impact of a car brand's luxury on the pricing process.
#
# However, it's essential to emphasize that these correlations are not absolute (i.e., not close to ±1). Consequently, the hypothesis suggesting stronger dependencies among these factors is proven false. The identified factors contribute to price formation but to a lesser extent than initially perceived, representing smaller percentages in the overall correlation structure.
